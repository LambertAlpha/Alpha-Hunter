# %% [markdown]
# # TFA vs Baselines - 完整对比实验
#
# 本notebook实现完整的对比实验，符合金融学术规范
#
# **对比模型**:
# - PCA + Ridge Regression
# - PCA + MLP
# - PCA + LSTM
# - **TFA (Ours)**
#
# **评估维度**:
# - IC, ICIR, Sharpe ratio
# - Statistical significance
# - Regime analysis
